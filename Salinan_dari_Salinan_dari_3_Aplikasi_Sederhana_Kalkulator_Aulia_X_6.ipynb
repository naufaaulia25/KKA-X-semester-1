# %% [markdown]
# <a href="https://colab.research.google.com/github/naufaaulia25/KKA-X-semester-1/blob/main/Salinan_dari_Salinan_dari_3_Aplikasi_Sederhana_Kalkulator_Aulia_X_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm) : "  ))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")

# %%
jari_jari=int(input("Masukan jari jari tabung (cm): "))
tinggi=int(input("Masukan tinggi tabung (cm): "))

volume=22/7 * 10 * 10 * 30

print(f"\nVolume tabung yaitu {volume} cm^3")
